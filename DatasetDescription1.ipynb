# %% [markdown]
# <a href="https://colab.research.google.com/github/GutemaB2015/Gutema-thesis/blob/main/DatasetDescription1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# Load the dataset
data = pd.read_csv('https://raw.githubusercontent.com/GutemaB2015/Gutema-thesis/main/FillDataset.csv')

# Get descriptive statistics of the dataset
print(data.describe())

# Check for missing values
print("Number of missing values under each column \n",data.isnull().sum())

# Describe the missing values. at the contrary since our dataframe is full and there are no
# missing values.hence, it displays 0.
for column in data.columns:
    if data[column].isnull().any():
        print("Column name:", column)
        print("Number of missing values:", data[column].isnull().sum())
        print("Percentage of missing values:", (data[column].isnull().sum() / len(data)) * 100)

# Print the data types of the columns
print("Data types:", data.dtypes)

# Print the summary statistics of the columns
print("Summary statistics:", data.describe())

# Print the number of missing values
print("Number of missing values:", data.isnull().sum())

# Print the unique values in each column
for column in data.columns:
    print("Unique values in column", column, ":", len(data[column].unique()))

# Print the correlation matrix
print("Correlation matrix:", data.corr())



# [ here below is the describtion of above code ]


# This code will first import the necessary libraries, then create a dataset.
# Next, it will use the describe() method of the pandas DataFrame class to get descriptive statistics of the dataset.
# The describe() method returns a table that shows the count, mean, standard deviation, minimum value,
# 25th percentile, 50th percentile (median), 75th percentile, and maximum value for each column in the dataset.

# The descriptive statistics of a dataset can be used to understand the distribution of the data and identify any outliers.
# Outliers are data points that are significantly different from the rest of the data.
# Outliers can sometimes be caused by errors in data collection or processing.
# Out:
#        Destination_Port  Flow_Duration  Total_Fwd_Packets  \
# count       2999.000000   2.999000e+03        2999.000000
# mean        4875.892297   2.429287e+07           7.300433
# std        15422.164704   3.470811e+07          11.485355
# min           21.000000   0.000000e+00           1.000000
# 25%           80.000000   3.070500e+04           2.000000
# 50%           80.000000   6.801500e+05           6.000000
# 75%           80.000000   4.963662e+07          10.000000
# max        65534.000000   1.199731e+08         394.000000
#
#        Total_Backward_Packets  Total_Length_of_Fwd_Packets  \
# count             2999.000000                  2999.000000
# mean                 3.070023                   594.946982
# std                 20.497004                  8100.086058
# min                  0.000000                     0.000000
# 25%                  1.000000                    62.000000
# 50%                  1.000000                   243.000000
# 75%                  2.000000                   493.500000
# max                692.000000                435953.000000
#
#        Total_Length_of_Bwd_Packets  Fwd_Packet_Length_Max  \
# count                 2.999000e+03            2999.000000
# mean                  1.973155e+03             238.454818
# std                   3.175941e+04             388.034611
# min                   0.000000e+00               0.000000
# 25%                   0.000000e+00              37.000000
# 50%                   0.000000e+00             168.000000
# 75%                   1.260000e+02             349.000000
# max                   1.160103e+06           14156.000000
#
#        Fwd_Packet_Length_Min  Fwd_Packet_Length_Mean  Fwd_Packet_Length_Std  \
# count            2999.000000             2999.000000            2999.000000
# mean                9.455485               51.665741              85.388313
# std                20.672466               77.382981             120.072621
# min                 0.000000                0.000000               0.000000
# 25%                 0.000000               26.250000               0.000000
# 50%                 0.000000               42.000000              61.406918
# 75%                 6.000000               59.666667             132.375224
# max               341.000000             1773.125000            2377.682376
#
#        ...  act_data_pkt_fwd  min_seg_size_forward   Active_Mean  \
# count  ...       2999.000000           2999.000000  2.999000e+03
# mean   ...          2.556519             12.032011  2.888850e+05
# std    ...          6.353710             13.919009  8.082842e+05
# min    ...          0.000000              0.000000  0.000000e+00
# 25%    ...          1.000000              0.000000  0.000000e+00
# 50%    ...          1.000000              0.000000  0.000000e+00
# 75%    ...          3.000000             20.000000  1.519098e+05
# max    ...        264.000000             44.000000  7.410634e+06
#
#          Active_Std    Active_Max    Active_Min     Idle_Mean      Idle_Std  \
# count  2.999000e+03  2.999000e+03  2.999000e+03  2.999000e+03  2.999000e+03
# mean   1.563217e+05  4.287688e+05  1.805778e+05  1.330568e+07  2.469289e+06
# std    5.385956e+05  1.174714e+06  7.088763e+05  2.344043e+07  7.097978e+06
# min    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 25%    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 50%    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 75%    0.000000e+00  2.079140e+05  2.954650e+04  1.925614e+07  0.000000e+00
# max    7.205544e+06  2.480604e+07  7.410634e+06  1.200000e+08  6.960000e+07
#
#            Idle_Max      Idle_Min
# count  2.999000e+03  2.999000e+03
# mean   1.546014e+07  1.135292e+07
# std    2.555595e+07  2.266919e+07
# min    0.000000e+00  0.000000e+00
# 25%    0.000000e+00  0.000000e+00
# 50%    0.000000e+00  0.000000e+00
# 75%    2.506238e+07  1.200000e+07
# max    1.200000e+08  1.200000e+08
#
# [8 rows x 77 columns]
# Number of missing values under each column
#  Destination_Port               0
# Flow_Duration                  0
# Total_Fwd_Packets              0
# Total_Backward_Packets         0
# Total_Length_of_Fwd_Packets    0
#                               ..
# Idle_Mean                      0
# Idle_Std                       0
# Idle_Max                       0
# Idle_Min                       0
# Label                          0
# Length: 78, dtype: int64
# Data types: Destination_Port                 int64
# Flow_Duration                    int64
# Total_Fwd_Packets                int64
# Total_Backward_Packets           int64
# Total_Length_of_Fwd_Packets      int64
#                                 ...
# Idle_Mean                      float64
# Idle_Std                       float64
# Idle_Max                         int64
# Idle_Min                         int64
# Label                           object
# Length: 78, dtype: object
# Summary statistics:        Destination_Port  Flow_Duration  Total_Fwd_Packets  \
# count       2999.000000   2.999000e+03        2999.000000
# mean        4875.892297   2.429287e+07           7.300433
# std        15422.164704   3.470811e+07          11.485355
# min           21.000000   0.000000e+00           1.000000
# 25%           80.000000   3.070500e+04           2.000000
# 50%           80.000000   6.801500e+05           6.000000
# 75%           80.000000   4.963662e+07          10.000000
# max        65534.000000   1.199731e+08         394.000000
#
#        Total_Backward_Packets  Total_Length_of_Fwd_Packets  \
# count             2999.000000                  2999.000000
# mean                 3.070023                   594.946982
# std                 20.497004                  8100.086058
# min                  0.000000                     0.000000
# 25%                  1.000000                    62.000000
# 50%                  1.000000                   243.000000
# 75%                  2.000000                   493.500000
# max                692.000000                435953.000000
#
#        Total_Length_of_Bwd_Packets  Fwd_Packet_Length_Max  \
# count                 2.999000e+03            2999.000000
# mean                  1.973155e+03             238.454818
# std                   3.175941e+04             388.034611
# min                   0.000000e+00               0.000000
# 25%                   0.000000e+00              37.000000
# 50%                   0.000000e+00             168.000000
# 75%                   1.260000e+02             349.000000
# max                   1.160103e+06           14156.000000
#
#        Fwd_Packet_Length_Min  Fwd_Packet_Length_Mean  Fwd_Packet_Length_Std  \
# count            2999.000000             2999.000000            2999.000000
# mean                9.455485               51.665741              85.388313
# std                20.672466               77.382981             120.072621
# min                 0.000000                0.000000               0.000000
# 25%                 0.000000               26.250000               0.000000
# 50%                 0.000000               42.000000              61.406918
# 75%                 6.000000               59.666667             132.375224
# max               341.000000             1773.125000            2377.682376
#
#        ...  act_data_pkt_fwd  min_seg_size_forward   Active_Mean  \
# count  ...       2999.000000           2999.000000  2.999000e+03
# mean   ...          2.556519             12.032011  2.888850e+05
# std    ...          6.353710             13.919009  8.082842e+05
# min    ...          0.000000              0.000000  0.000000e+00
# 25%    ...          1.000000              0.000000  0.000000e+00
# 50%    ...          1.000000              0.000000  0.000000e+00
# 75%    ...          3.000000             20.000000  1.519098e+05
# max    ...        264.000000             44.000000  7.410634e+06
#
#          Active_Std    Active_Max    Active_Min     Idle_Mean      Idle_Std  \
# count  2.999000e+03  2.999000e+03  2.999000e+03  2.999000e+03  2.999000e+03
# mean   1.563217e+05  4.287688e+05  1.805778e+05  1.330568e+07  2.469289e+06
# std    5.385956e+05  1.174714e+06  7.088763e+05  2.344043e+07  7.097978e+06
# min    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 25%    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 50%    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 75%    0.000000e+00  2.079140e+05  2.954650e+04  1.925614e+07  0.000000e+00
# max    7.205544e+06  2.480604e+07  7.410634e+06  1.200000e+08  6.960000e+07
#
#            Idle_Max      Idle_Min
# count  2.999000e+03  2.999000e+03
# mean   1.546014e+07  1.135292e+07
# std    2.555595e+07  2.266919e+07
# min    0.000000e+00  0.000000e+00
# 25%    0.000000e+00  0.000000e+00
# 50%    0.000000e+00  0.000000e+00
# 75%    2.506238e+07  1.200000e+07
# max    1.200000e+08  1.200000e+08
#
# [8 rows x 77 columns]
# Number of missing values: Destination_Port               0
# Flow_Duration                  0
# Total_Fwd_Packets              0
# Total_Backward_Packets         0
# Total_Length_of_Fwd_Packets    0
#                               ..
# Idle_Mean                      0
# Idle_Std                       0
# Idle_Max                       0
# Idle_Min                       0
# Label                          0
# Length: 78, dtype: int64
# Unique values in column Destination_Port : 294
# Unique values in column Flow_Duration : 2685
# Unique values in column Total_Fwd_Packets : 52
# Unique values in column Total_Backward_Packets : 54
# Unique values in column Total_Length_of_Fwd_Packets : 765
# Unique values in column Total_Length_of_Bwd_Packets : 521
# Unique values in column Fwd_Packet_Length_Max : 394
# Unique values in column Fwd_Packet_Length_Min : 70
# Unique values in column Fwd_Packet_Length_Mean : 1184
# Unique values in column Fwd_Packet_Length_Std : 1404
# Unique values in column Bwd_Packet_Length_Max : 350
# Unique values in column Bwd_Packet_Length_Min : 202
# Unique values in column Bwd_Packet_Length_Mean : 505
# Unique values in column Bwd_Packet_Length_Std : 326
# Unique values in column Flow_Bytes_Sec : 2607
# Unique values in column Flow_Packets_Sec : 2698
# Unique values in column Flow_IAT_Mean : 2680
# Unique values in column Flow_IAT_Std : 2240
# Unique values in column Flow_IAT_Max : 2439
# Unique values in column Flow_IAT_Min : 755
# Unique values in column Fwd_IAT_Total : 1927
# Unique values in column Fwd_IAT_Mean : 2130
# Unique values in column Fwd_IAT_Std : 1799
# Unique values in column Fwd_IAT_Max : 1906
# Unique values in column Fwd_IAT_Min : 650
# Unique values in column Bwd_IAT_Total : 396
# Unique values in column Bwd_IAT_Mean : 397
# Unique values in column Bwd_IAT_Std : 357
# Unique values in column Bwd_IAT_Max : 394
# Unique values in column Bwd_IAT_Min : 166
# Unique values in column Fwd_PSH_Flags : 2
# Unique values in column Bwd_PSH_Flags : 2
# Unique values in column Fwd_URG_Flags : 1
# Unique values in column Bwd_URG_Flags : 1
# Unique values in column Fwd_Header_Length : 234
# Unique values in column Bwd_Header_Length : 118
# Unique values in column Fwd_Packets_Sec : 2687
# Unique values in column Bwd_Packets_Sec : 2609
# Unique values in column Min_Packet_Length : 69
# Unique values in column Max_Packet_Length : 492
# Unique values in column Packet_Length_Mean : 1510
# Unique values in column Packet_Length_Std : 1645
# Unique values in column Packet_Length_Variance : 1645
# Unique values in column FIN_Flag_Count : 2
# Unique values in column SYN_Flag_Count : 2
# Unique values in column RST_Flag_Count : 2
# Unique values in column PSH_Flag_Count : 2
# Unique values in column ACK_Flag_Count : 2
# Unique values in column URG_Flag_Count : 2
# Unique values in column CWE_Flag_Count : 1
# Unique values in column ECE_Flag_Count : 1
# Unique values in column Down_Up_Ratio : 6
# Unique values in column Average_Packet_Size : 1465
# Unique values in column Avg_Fwd_Segment_Size : 1184
# Unique values in column Avg_Bwd_Segment_Size : 505
# Unique values in column Fwd_Avg_Bytes_Bulk : 1
# Unique values in column Fwd_Avg_Packets_Bulk : 1
# Unique values in column Fwd_Avg_Bulk_Rate : 1
# Unique values in column Bwd_Avg_Bytes_Bulk : 1
# Unique values in column Bwd_Avg_Packets_Bulk : 1
# Unique values in column Bwd_Avg_Bulk_Rate : 1
# Unique values in column Subflow_Fwd_Packets : 52
# Unique values in column Subflow_Fwd_Bytes : 765
# Unique values in column Subflow_Bwd_Packets : 54
# Unique values in column Subflow_Bwd_Bytes : 521
# Unique values in column Init_Win_bytes_forward : 199
# Unique values in column Init_Win_bytes_backward : 226
# Unique values in column act_data_pkt_fwd : 35
# Unique values in column min_seg_size_forward : 6
# Unique values in column Active_Mean : 1114
# Unique values in column Active_Std : 604
# Unique values in column Active_Max : 1115
# Unique values in column Active_Min : 1089
# Unique values in column Idle_Mean : 946
# Unique values in column Idle_Std : 664
# Unique values in column Idle_Max : 921
# Unique values in column Idle_Min : 932
# Unique values in column Label : 3
# Correlation matrix:                              Destination_Port  Flow_Duration  \
# Destination_Port                     1.000000      -0.215845
# Flow_Duration                       -0.215845       1.000000
# Total_Fwd_Packets                   -0.150400       0.392562
# Total_Backward_Packets              -0.032845       0.104136
# Total_Length_of_Fwd_Packets         -0.017707       0.076196
# ...                                       ...            ...
# Active_Min                          -0.078854       0.226530
# Idle_Mean                           -0.175900       0.800143
# Idle_Std                            -0.107936       0.511585
# Idle_Max                            -0.187499       0.856979
# Idle_Min                            -0.155168       0.702583
#
#                              Total_Fwd_Packets  Total_Backward_Packets  \
# Destination_Port                     -0.150400               -0.032845
# Flow_Duration                         0.392562                0.104136
# Total_Fwd_Packets                     1.000000                0.862874
# Total_Backward_Packets                0.862874                1.000000
# Total_Length_of_Fwd_Packets           0.447913                0.419973
# ...                                        ...                     ...
# Active_Min                            0.133067                0.018420
# Idle_Mean                             0.240428                0.012315
# Idle_Std                              0.167519               -0.021640
# Idle_Max                              0.260353                0.006492
# Idle_Min                              0.208652                0.017446
#
#                              Total_Length_of_Fwd_Packets  \
# Destination_Port                               -0.017707
# Flow_Duration                                   0.076196
# Total_Fwd_Packets                               0.447913
# Total_Backward_Packets                          0.419973
# Total_Length_of_Fwd_Packets                     1.000000
# ...                                                  ...
# Active_Min                                      0.070263
# Idle_Mean                                       0.005739
# Idle_Std                                        0.007239
# Idle_Max                                        0.008707
# Idle_Min                                        0.004342
#
#                              Total_Length_of_Bwd_Packets  \
# Destination_Port                               -0.018095
# Flow_Duration                                   0.071597
# Total_Fwd_Packets                               0.822843
# Total_Backward_Packets                          0.980527
# Total_Length_of_Fwd_Packets                     0.294414
# ...                                                  ...
# Active_Min                                      0.013338
# Idle_Mean                                       0.018711
# Idle_Std                                       -0.017131
# Idle_Max                                        0.013388
# Idle_Min                                        0.023205
#
#                              Fwd_Packet_Length_Max  Fwd_Packet_Length_Min  \
# Destination_Port                         -0.157736              -0.085273
# Flow_Duration                             0.183360              -0.267211
# Total_Fwd_Packets                         0.489048              -0.211563
# Total_Backward_Packets                    0.359522              -0.031807
# Total_Length_of_Fwd_Packets               0.737089              -0.027383
# ...                                            ...                    ...
# Active_Min                                0.081386              -0.114469
# Idle_Mean                                 0.098699              -0.190389
# Idle_Std                                  0.028234              -0.159158
# Idle_Max                                  0.096531              -0.213200
# Idle_Min                                  0.096212              -0.157467
#
#                              Fwd_Packet_Length_Mean  Fwd_Packet_Length_Std  \
# Destination_Port                          -0.129926              -0.172196
# Flow_Duration                              0.031499               0.159120
# Total_Fwd_Packets                          0.245099               0.348402
# Total_Backward_Packets                     0.202830               0.210426
# Total_Length_of_Fwd_Packets                0.499325               0.462030
# ...                                             ...                    ...
# Active_Min                                 0.053591               0.076995
# Idle_Mean                                 -0.005644               0.106939
# Idle_Std                                  -0.020330               0.028778
# Idle_Max                                  -0.008736               0.104083
# Idle_Min                                   0.000235               0.104958
#
#                              ...  act_data_pkt_fwd  min_seg_size_forward  \
# Destination_Port             ...         -0.105139              0.333288
# Flow_Duration                ...          0.262981             -0.372280
# Total_Fwd_Packets            ...          0.602957             -0.130724
# Total_Backward_Packets       ...          0.489116              0.109733
# Total_Length_of_Fwd_Packets  ...          0.791108              0.011124
# ...                          ...               ...                   ...
# Active_Min                   ...          0.101087             -0.171569
# Idle_Mean                    ...          0.065240             -0.382086
# Idle_Std                     ...          0.100301             -0.278706
# Idle_Max                     ...          0.088039             -0.418232
# Idle_Min                     ...          0.041033             -0.327094
#
#                              Active_Mean  Active_Std  Active_Max  Active_Min  \
# Destination_Port               -0.110673   -0.089802   -0.112775   -0.078854
# Flow_Duration                   0.370884    0.380325    0.430591    0.226530
# Total_Fwd_Packets               0.225843    0.269281    0.360885    0.133067
# Total_Backward_Packets          0.064326    0.137781    0.191410    0.018420
# Total_Length_of_Fwd_Packets     0.152335    0.261120    0.408893    0.070263
# ...                                  ...         ...         ...         ...
# Active_Min                      0.887481    0.024827    0.627699    1.000000
# Idle_Mean                       0.268935    0.122565    0.223097    0.239169
# Idle_Std                        0.230097    0.333602    0.270088    0.079385
# Idle_Max                        0.309459    0.196331    0.277446    0.244854
# Idle_Min                        0.222558    0.042283    0.163770    0.230265
#
#                              Idle_Mean  Idle_Std  Idle_Max  Idle_Min
# Destination_Port             -0.175900 -0.107936 -0.187499 -0.155168
# Flow_Duration                 0.800143  0.511585  0.856979  0.702583
# Total_Fwd_Packets             0.240428  0.167519  0.260353  0.208652
# Total_Backward_Packets        0.012315 -0.021640  0.006492  0.017446
# Total_Length_of_Fwd_Packets   0.005739  0.007239  0.008707  0.004342
# ...                                ...       ...       ...       ...
# Active_Min                    0.239169  0.079385  0.244854  0.230265
# Idle_Mean                     1.000000  0.259119  0.973586  0.974273
# Idle_Std                      0.259119  1.000000  0.464428  0.038286
# Idle_Max                      0.973586  0.464428  1.000000  0.899809
# Idle_Min                      0.974273  0.038286  0.899809  1.000000
#
# [77 rows x 77 columns]
# <ipython-input-1-be8ebf9fbf1d>:34: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   print("Correlation matrix:", data.corr())
